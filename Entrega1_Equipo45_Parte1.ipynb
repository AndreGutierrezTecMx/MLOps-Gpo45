# %% [markdown]
# **MAESTRÍA EN INTELIGENCIA ARTIFICIAL APLICADA**
#
# **Curso: MLOPS**
#
# Tecnológico de Monterrey
#
#
# **Proyecto Entrega 1**
#
#
# ---

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
DIR ="/content/drive/MyDrive/Master/MLops"
os.chdir(DIR)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('online_news_modified.csv', delimiter=',')

# %% [markdown]
# # ***EDA***

# %% [markdown]
# Estadísticas descriptivas para todas las variables del dataframe.

# %%
#PRIMERAS FILAS
df.head()
# Out:
#                                                  url timedelta n_tokens_title  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...     731.0           12.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...     731.0            9.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...     731.0            9.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...     731.0            9.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/     731.0           13.0
#
#   n_tokens_content  n_unique_tokens n_non_stop_words n_non_stop_unique_tokens  \
# 0            219.0   0.663594466988   0.999999992308           0.815384609112
# 1            255.0   0.604743080614   0.999999993289            0.79194630341
# 2            211.0   0.575129530699   0.999999991597            0.66386554064
# 3            531.0   0.503787877834   0.999999996904           0.665634672862
# 4           1072.0   0.41564561695    0.999999998565           0.540889525766
#
#   num_hrefs num_self_hrefs num_imgs  ... max_positive_polarity  \
# 0       4.0            2.0      1.0  ...                   0.7
# 1       3.0            1.0      1.0  ...                   0.7
# 2      3.0             1.0     1.0   ...                   1.0
# 3       9.0            0.0      1.0  ...                   0.8
# 4      19.0           19.0     20.0  ...                   1.0
#
#   avg_negative_polarity min_negative_polarity max_negative_polarity  \
# 0                 -0.35                  -0.6   -3.4000000000000004
# 1              -0.11875                -0.125                  -0.1
# 2       -0.466666666667                  -0.8       -0.133333333333
# 3       -0.369696969697                  -0.6       -0.166666666667
# 4       -0.220192307692                 error                 -0.05
#
#   title_subjectivity title_sentiment_polarity abs_title_subjectivity  \
# 0                0.5                  -0.1875                   0.0
# 1                0.0                      0.0                    0.5
# 2                0.0                      0.0                    0.5
# 3                0.0                      0.0                    0.5
# 4     0.454545454545           0.136363636364        0.0454545454545
#
#   abs_title_sentiment_polarity    shares mixed_type_col
# 0                       0.1875     593.0            bad
# 1                          0.0     711.0            639
# 2                          0.0   1500.0         unknown
# 3                          NaN    1200.0            688
# 4               0.136363636364     505.0            579
#
# [5 rows x 62 columns]

# %%
#INFORMACIÓN DE TIPOS DE DATOS
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40436 entries, 0 to 40435
# Data columns (total 62 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            40027 non-null  object
#  1   timedelta                      39994 non-null  object
#  2   n_tokens_title                 39976 non-null  object
#  3   n_tokens_content               39963 non-null  object
#  4   n_unique_tokens                39985 non-null  object
#  5   n_non_stop_words               39977 non-null  object
#  6   n_non_stop_unique_tokens       39956 non-null  object
#  7   num_hrefs                      39986 non-null  object
#  8   num_self_hrefs                 39988 non-null  object
#  9   num_imgs                       39980 non-null  object
#  10  num_videos                     39987 non-null  object
#  11  average_token_length           40031 non-null  object
#  12  num_keywords                   39981 non-null  object
#  13  data_channel_is_lifestyle      39961 non-null  object
#  14  data_channel_is_entertainment  39951 non-null  object
#  15  data_channel_is_bus            40029 non-null  object
#  16  data_channel_is_socmed         39944 non-null  object
#  17  data_channel_is_tech           39993 non-null  object
#  18  data_channel_is_world          39984 non-null  object
#  19  kw_min_min                     39984 non-null  object
#  20  kw_max_min                     39972 non-null  object
#  21  kw_avg_min                     39965 non-null  object
#  22  kw_min_max                     39995 non-null  object
#  23  kw_max_max                     40031 non-null  object
#  24  kw_avg_max                     39958 non-null  object
#  25  kw_min_avg                     40004 non-null  object
#  26  kw_max_avg                     39996 non-null  object
#  27  kw_avg_avg                     40035 non-null  object
#  28  self_reference_min_shares      39997 non-null  object
#  29  self_reference_max_shares      39972 non-null  object
#  30  self_reference_avg_sharess     39970 non-null  object
#  31  weekday_is_monday              39977 non-null  object
#  32  weekday_is_tuesday             39977 non-null  object
#  33  weekday_is_wednesday           40015 non-null  object
#  34  weekday_is_thursday            39977 non-null  object
#  35  weekday_is_friday              40007 non-null  object
#  36  weekday_is_saturday            39980 non-null  object
#  37  weekday_is_sunday              39966 non-null  object
#  38  is_weekend                     39969 non-null  object
#  39  LDA_00                         39945 non-null  object
#  40  LDA_01                         39982 non-null  object
#  41  LDA_02                         39953 non-null  object
#  42  LDA_03                         39989 non-null  object
#  43  LDA_04                         39980 non-null  object
#  44  global_subjectivity            39999 non-null  object
#  45  global_sentiment_polarity      39996 non-null  object
#  46  global_rate_positive_words     39991 non-null  object
#  47  global_rate_negative_words     39948 non-null  object
#  48  rate_positive_words            39983 non-null  object
#  49  rate_negative_words            39956 non-null  object
#  50  avg_positive_polarity          39978 non-null  object
#  51  min_positive_polarity          39953 non-null  object
#  52  max_positive_polarity          39979 non-null  object
#  53  avg_negative_polarity          39975 non-null  object
#  54  min_negative_polarity          39976 non-null  object
#  55  max_negative_polarity          39996 non-null  object
#  56  title_subjectivity             39983 non-null  object
#  57  title_sentiment_polarity       39950 non-null  object
#  58  abs_title_subjectivity         39961 non-null  object
#  59  abs_title_sentiment_polarity   39981 non-null  object
#  60  shares                         39949 non-null  object
#  61  mixed_type_col                 36362 non-null  object
# dtypes: object(62)
# memory usage: 19.1+ MB

# %%
#ESTADÍSTICAS DESCRIPTIVAS
df.describe()
# Out:
#           url timedelta n_tokens_title n_tokens_content n_unique_tokens  \
# count   40027     39994          39976            39963           39985
# unique  39313      1677            363             3509           28030
# top      NAN       84.0           10.0              0.0             0.0
# freq       17       100           6984             1131            1131
#
#        n_non_stop_words n_non_stop_unique_tokens num_hrefs num_self_hrefs  \
# count             39977                    39956     39986          39988
# unique             2542                    24007       526            379
# top                 0.0                      0.0       5.0            2.0
# freq               1116                     1112      3282           7210
#
#        num_imgs  ... max_positive_polarity avg_negative_polarity  \
# count     39980  ...                 39979                 39975
# unique      390  ...                   402                 14718
# top         1.0  ...                   1.0                   0.0
# freq      17112  ...                 14009                  2420
#
#        min_negative_polarity max_negative_polarity title_subjectivity  \
# count                  39976                 39996              39983
# unique                   466                   428               1120
# top                     -0.5                 -0.05                0.0
# freq                    6472                  9393              17096
#
#        title_sentiment_polarity abs_title_subjectivity  \
# count                     39950                  39961
# unique                     1228                    989
# top                         0.0                    0.5
# freq                      18940                  19379
#
#        abs_title_sentiment_polarity  shares mixed_type_col
# count                         39981   39949          36362
# unique                         1062    2311           1002
# top                             0.0  1100.0        unknown
# freq                          18937    2184           4034
#
# [4 rows x 62 columns]

# %%
#ANÁLISIS DE VALORES NULOS
null_counts = df.isnull().sum()
null_percentages = (df.isnull().sum() / len(df)) * 100
null_info = pd.DataFrame({
    'Nulos': null_counts,
    'Porcentaje': null_percentages
})
null_info = null_info[null_info['Nulos'] > 0].sort_values('Nulos', ascending=False)
print(null_info)
# Out:
#                             Nulos  Porcentaje
# mixed_type_col               4074   10.075181
# data_channel_is_socmed        492    1.216738
# LDA_00                        491    1.214265
# global_rate_negative_words    488    1.206845
# shares                        487    1.204372
# ...                           ...         ...
# url                           409    1.011475
# data_channel_is_bus           407    1.006529
# average_token_length          405    1.001583
# kw_max_max                    405    1.001583
# kw_avg_avg                    401    0.991691
#
# [62 rows x 2 columns]

# %%
#ANÁLISIS DE VALORES VACÍOS (strings vacíos)
empty_counts = {}
for col in df.columns:
    if df[col].dtype == 'object':
        empty_count = (df[col] == '').sum()
        if empty_count > 0:
            empty_counts[col] = empty_count

if empty_counts:
    print("\nValores vacíos encontrados:")
    for col, count in empty_counts.items():
        print(f"   {col}: {count} ({count/len(df)*100:.2f}%)")
else:
    print("\nNo se encontraron valores vacíos (strings vacíos)")
# Out:
# No se encontraron valores vacíos (strings vacíos)

# %%
#ANÁLISIS DE DUPLICADOS
duplicates = df.duplicated().sum()
print(f"\nFilas duplicadas: {duplicates}")
# Out:
# Filas duplicadas: 0

# %%
#ANÁLISIS DE COLUMNAS
print("\nColumnas numéricas vs categóricas:")
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()
print(f"   Numéricas: {len(numeric_cols)}")
print(f"   Categóricas/Object: {len(categorical_cols)}")

if categorical_cols:
    print("\nColumnas categóricas:")
    for col in categorical_cols:
        print(f"   - {col}")
# Out:
# Columnas numéricas vs categóricas:
#    Numéricas: 0
#    Categóricas/Object: 62
#
# Columnas categóricas:
#    - url
#    - timedelta
#    - n_tokens_title
#    - n_tokens_content
#    - n_unique_tokens
#    - n_non_stop_words
#    - n_non_stop_unique_tokens
#    - num_hrefs
#    - num_self_hrefs
#    - num_imgs
#    - num_videos
#    - average_token_length
#    - num_keywords
#    - data_channel_is_lifestyle
#    - data_channel_is_entertainment
#    - data_channel_is_bus
#    - data_channel_is_socmed
#    - data_channel_is_tech
#    - data_channel_is_world
#    - kw_min_min
#    - kw_max_min
#    - kw_avg_min
#    - kw_min_max
#    - kw_max_max
#    - kw_avg_max
#    - kw_min_avg
#    - kw_max_avg
#    - kw_avg_avg
#    - self_reference_min_shares
#    - self_reference_max_shares
#    - self_reference_avg_sharess
#    - weekday_is_monday
#    - weekday_is_tuesday
#    - weekday_is_wednesday
#    - weekday_is_thursday
#    - weekday_is_friday
#    - weekday_is_saturday
#    - weekday_is_sunday
#    - is_weekend
#    - LDA_00
#    - LDA_01
#    - LDA_02
#    - LDA_03
#    - LDA_04
#    - global_subjectivity
#    - global_sentiment_polarity
#    - global_rate_positive_words
#    - global_rate_negative_words
#    - rate_positive_words
#    - rate_negative_words
#    - avg_positive_polarity
#    - min_positive_polarity
#    - max_positive_polarity
#    - avg_negative_polarity
#    - min_negative_polarity
#    - max_negative_polarity
#    - title_subjectivity
#    - title_sentiment_polarity
#    - abs_title_subjectivity
#    - abs_title_sentiment_polarity
#    - shares
#    - mixed_type_col

# %%
#ANÁLISIS DE VALORES ÚNICOS
if categorical_cols:
    for col in categorical_cols[:10]:  # Primeras 10 para no saturar
        unique_count = df[col].nunique()
        print(f"\n{col}:")
        print(f"   Valores únicos: {unique_count}")
        if unique_count < 20:
            print(f"   Valores: {df[col].unique()[:10]}")
else:
    print("\n   ✓ No hay columnas categóricas para analizar")
# Out:
# url:
#    Valores únicos: 39313
#
# timedelta:
#    Valores únicos: 1677
#
# n_tokens_title:
#    Valores únicos: 363
#
# n_tokens_content:
#    Valores únicos: 3509
#
# n_unique_tokens:
#    Valores únicos: 28030
#
# n_non_stop_words:
#    Valores únicos: 2542
#
# n_non_stop_unique_tokens:
#    Valores únicos: 24007
#
# num_hrefs:
#    Valores únicos: 526
#
# num_self_hrefs:
#    Valores únicos: 379
#
# num_imgs:
#    Valores únicos: 390

# %%
#CONVERSIÓN DE TIPOS DE DATOS
# Intentar convertir columnas que deberían ser numéricas
print("\nConvirtiendo columnas a tipos numéricos...")
for col in df.columns:
    if col != 'url':  # Excluir URL
        try:
            df[col] = pd.to_numeric(df[col], errors='coerce')
            print(f"   ✓ {col} convertida a numérico")
        except:
            pass

print("\nTipos de datos después de conversión:")
print(df.dtypes)
# Out:
# Convirtiendo columnas a tipos numéricos...
#    ✓ timedelta convertida a numérico
#    ✓ n_tokens_title convertida a numérico
#    ✓ n_tokens_content convertida a numérico
#    ✓ n_unique_tokens convertida a numérico
#    ✓ n_non_stop_words convertida a numérico
#    ✓ n_non_stop_unique_tokens convertida a numérico
#    ✓ num_hrefs convertida a numérico
#    ✓ num_self_hrefs convertida a numérico
#    ✓ num_imgs convertida a numérico
#    ✓ num_videos convertida a numérico
#    ✓ average_token_length convertida a numérico
#    ✓ num_keywords convertida a numérico
#    ✓ data_channel_is_lifestyle convertida a numérico
#    ✓ data_channel_is_entertainment convertida a numérico
#    ✓ data_channel_is_bus convertida a numérico
#    ✓ data_channel_is_socmed convertida a numérico
#    ✓ data_channel_is_tech convertida a numérico
#    ✓ data_channel_is_world convertida a numérico
#    ✓ kw_min_min convertida a numérico
#    ✓ kw_max_min convertida a numérico
#    ✓ kw_avg_min convertida a numérico
#    ✓ kw_min_max convertida a numérico
#    ✓ kw_max_max convertida a numérico
#    ✓ kw_avg_max convertida a numérico
#    ✓ kw_min_avg convertida a numérico
#    ✓ kw_max_avg convertida a numérico
#    ✓ kw_avg_avg convertida a numérico
#    ✓ self_reference_min_shares convertida a numérico
#    ✓ self_reference_max_shares convertida a numérico
#    ✓ self_reference_avg_sharess convertida a numérico
#    ✓ weekday_is_monday convertida a numérico
#    ✓ weekday_is_tuesday convertida a numérico
#    ✓ weekday_is_wednesday convertida a numérico
#    ✓ weekday_is_thursday convertida a numérico
#    ✓ weekday_is_friday convertida a numérico
#    ✓ weekday_is_saturday convertida a numérico
#    ✓ weekday_is_sunday convertida a numérico
#    ✓ is_weekend convertida a numérico
#    ✓ LDA_00 convertida a numérico
#    ✓ LDA_01 convertida a numérico
#    ✓ LDA_02 convertida a numérico
#    ✓ LDA_03 convertida a numérico
#    ✓ LDA_04 convertida a numérico
#    ✓ global_subjectivity convertida a numérico
#    ✓ global_sentiment_polarity convertida a numérico
#    ✓ global_rate_positive_words convertida a numérico
#    ✓ global_rate_negative_words convertida a numérico
#    ✓ rate_positive_words convertida a numérico
#    ✓ rate_negative_words convertida a numérico
#    ✓ avg_positive_polarity convertida a numérico
#    ✓ min_positive_polarity convertida a numérico
#    ✓ max_positive_polarity convertida a numérico
#    ✓ avg_negative_polarity convertida a numérico
#    ✓ min_negative_polarity convertida a numérico
#    ✓ max_negative_polarity convertida a numérico
#    ✓ title_subjectivity convertida a numérico
#    ✓ title_sentiment_polarity convertida a numérico
#    ✓ abs_title_subjectivity convertida a numérico
#    ✓ abs_title_sentiment_polarity convertida a numérico
#    ✓ shares convertida a numérico
#    ✓ mixed_type_col convertida a numérico
#
# Tipos de datos después de conversión:
# url                              object
# timedelta                       float64
# n_tokens_title                  float64
# n_tokens_content                float64
# n_unique_tokens                 float64
#                                  ...
# title_sentiment_polarity        float64
# abs_title_subjectivity          float64
# abs_title_sentiment_polarity    float64
# shares                          float64
# mixed_type_col                  float64
# Length: 62, dtype: object

# %% [markdown]
# # ***LIMPIEZA DE DATOS***

# %%
#PROCESO DE LIMPIEZA
df_clean = df.copy()

# %%
#CONVERSION DE TIPOS DE DATOS
# Intentar convertir columnas que deberían ser numéricas
print("\nConvirtiendo columnas a tipos numéricos...")
conversion_count = 0
for col in df_clean.columns:
    if col != 'url':  # Excluir URL
        original_dtype = df_clean[col].dtype
        df_clean[col] = pd.to_numeric(df_clean[col], errors='coerce')
        if df_clean[col].dtype != original_dtype:
            print(f"   ✓ {col} convertida de {original_dtype} a {df_clean[col].dtype}")
            conversion_count += 1

print(f"\nTotal de columnas convertidas: {conversion_count}")
# Out:
# Convirtiendo columnas a tipos numéricos...
#    ✓ timedelta convertida de object a float64
#    ✓ n_tokens_title convertida de object a float64
#    ✓ n_tokens_content convertida de object a float64
#    ✓ n_unique_tokens convertida de object a float64
#    ✓ n_non_stop_words convertida de object a float64
#    ✓ n_non_stop_unique_tokens convertida de object a float64
#    ✓ num_hrefs convertida de object a float64
#    ✓ num_self_hrefs convertida de object a float64
#    ✓ num_imgs convertida de object a float64
#    ✓ num_videos convertida de object a float64
#    ✓ average_token_length convertida de object a float64
#    ✓ num_keywords convertida de object a float64
#    ✓ data_channel_is_lifestyle convertida de object a float64
#    ✓ data_channel_is_entertainment convertida de object a float64
#    ✓ data_channel_is_bus convertida de object a float64
#    ✓ data_channel_is_socmed convertida de object a float64
#    ✓ data_channel_is_tech convertida de object a float64
#    ✓ data_channel_is_world convertida de object a float64
#    ✓ kw_min_min convertida de object a float64
#    ✓ kw_max_min convertida de object a float64
#    ✓ kw_avg_min convertida de object a float64
#    ✓ kw_min_max convertida de object a float64
#    ✓ kw_max_max convertida de object a float64
#    ✓ kw_avg_max convertida de object a float64
#    ✓ kw_min_avg convertida de object a float64
#    ✓ kw_max_avg convertida de object a float64
#    ✓ kw_avg_avg convertida de object a float64
#    ✓ self_reference_min_shares convertida de object a float64
#    ✓ self_reference_max_shares convertida de object a float64
#    ✓ self_reference_avg_sharess convertida de object a float64
#    ✓ weekday_is_monday convertida de object a float64
#    ✓ weekday_is_tuesday convertida de object a float64
#    ✓ weekday_is_wednesday convertida de object a float64
#    ✓ weekday_is_thursday convertida de object a float64
#    ✓ weekday_is_friday convertida de object a float64
#    ✓ weekday_is_saturday convertida de object a float64
#    ✓ weekday_is_sunday convertida de object a float64
#    ✓ is_weekend convertida de object a float64
#    ✓ LDA_00 convertida de object a float64
#    ✓ LDA_01 convertida de object a float64
#    ✓ LDA_02 convertida de object a float64
#    ✓ LDA_03 convertida de object a float64
#    ✓ LDA_04 convertida de object a float64
#    ✓ global_subjectivity convertida de object a float64
#    ✓ global_sentiment_polarity convertida de object a float64
#    ✓ global_rate_positive_words convertida de object a float64
#    ✓ global_rate_negative_words convertida de object a float64
#    ✓ rate_positive_words convertida de object a float64
#    ✓ rate_negative_words convertida de object a float64
#    ✓ avg_positive_polarity convertida de object a float64
#    ✓ min_positive_polarity convertida de object a float64
#    ✓ max_positive_polarity convertida de object a float64
#    ✓ avg_negative_polarity convertida de object a float64
#    ✓ min_negative_polarity convertida de object a float64
#    ✓ max_negative_polarity convertida de object a float64
#    ✓ title_subjectivity convertida de object a float64
#    ✓ title_sentiment_polarity convertida de object a float64
#    ✓ abs_title_subjectivity convertida de object a float64
#    ✓ abs_title_sentiment_polarity convertida de object a float64
#    ✓ shares convertida de object a float64
#    ✓ mixed_type_col convertida de object a float64
#
# Total de columnas convertidas: 61

# %%
#NORMALIZACIÓN DE COLUMNAS BOOLEANAS
# Definir columnas que deben ser booleanas (0 o 1)
boolean_cols = [
    'data_channel_is_lifestyle',
    'data_channel_is_entertainment',
    'data_channel_is_bus',
    'data_channel_is_socmed',
    'data_channel_is_tech',
    'data_channel_is_world',
    'weekday_is_monday',
    'weekday_is_tuesday',
    'weekday_is_wednesday',
    'weekday_is_thursday',
    'weekday_is_friday',
    'weekday_is_saturday',
    'weekday_is_sunday',
    'is_weekend'
]

print("\nNormalizando columnas booleanas (0 si es 0, 1 si es cualquier otro valor):")
for col in boolean_cols:
    if col in df_clean.columns:
        # Mostrar valores únicos antes de la normalización
        unique_before = df_clean[col].unique()
        print(f"\n   {col}:")
        print(f"      Valores únicos antes: {sorted(unique_before[~pd.isna(unique_before)])}")

        # Normalizar: 0 se queda como 0, cualquier otro valor se convierte en 1
        df_clean.loc[:, col] = df_clean[col].apply(lambda x: 0 if x == 0 else (1 if pd.notna(x) else np.nan))

        # Mostrar valores únicos después de la normalización
        unique_after = df_clean[col].unique()
        print(f"      Valores únicos después: {sorted(unique_after[~pd.isna(unique_after)])}")

        # Contar valores
        value_counts = df_clean[col].value_counts()
        print(f"      Distribución: 0={value_counts.get(0, 0)}, 1={value_counts.get(1, 0)}")

print(f"\n✓ {len([col for col in boolean_cols if col in df_clean.columns])} columnas booleanas normalizadas")
# Out:
# Normalizando columnas booleanas (0 si es 0, 1 si es cualquier otro valor):
#
#    data_channel_is_lifestyle:
#       Valores únicos antes: [np.float64(0.0), np.float64(1.0), np.float64
0), np.float64(620.0), np.float64(627.0), np.float64(630.0), np.float64(648.0), np.float64(649.0), np.float64(655.0), np.float64(657.0), np.float64(664.0), np.float64(667.0), np.float64(676.0), np.float64(677.0), np.float64(681.0), np.float64(690.0), np.float64(707.0), np.float64(721.0), np.float64(723.0), np.float64(726.0), np.float64(729.0), np.float64(734.0), np.float64(735.0), np.float64(738.0), np.float64(745.0), np.float64(746.0), np.float64(750.0), np.float64(755.0), np.float64(768.0), np.float64(779.0), np.float64(785.0), np.float64(789.0), np.float64(790.0), np.float64(794.0), np.float64(796.0), np.float64(797.0), np.float64(798.0), np.float64(799.0), np.float64(804.0), np.float64(810.0), np.float64(822.0), np.float64(823.0), np.float64(825.0), np.float64(828.0), np.float64(829.0), np.float64(832.0), np.float64(841.0), np.float64(853.0), np.float64(855.0), np.float64(887.0), np.float64(888.0), np.float64(891.0), np.float64(899.0), np.float64(902.0), np.float64(911.0), np.float64(919.0), np.float64(922.0), np.float64(925.0), np.float64(926.0), np.float64(931.0), np.float64(932.0), np.float64(933.0), np.float64(934.0), np.float64(942.0), np.float64(949.0), np.float64(955.0), np.float64(960.0), np.float64(970.0), np.float64(971.0), np.float64(972.0), np.float64(975.0), np.float64(980.0), np.float64(982.0), np.float64(983.0), np.float64(988.0), np.float64(993.0), np.float64(996.0), np.float64(999.0), np.float64(1135.0), np ...
#       Valores únicos después: [np.float64(0.0), np.float64(1.0)]
#       Distribución: 0=34413, 1=5396
#
# ✓ 14 columnas booleanas normalizadas

# %%
#ANÁLISIS DE OUTLIERS
# Seleccionar columnas numéricas importantes (excluyendo las booleanas)
important_numeric_cols = ['n_tokens_title', 'n_tokens_content', 'num_hrefs',
                          'num_imgs', 'num_videos', 'shares']

for col in important_numeric_cols:
    if col in df_clean.columns and df_clean[col].dtype in ['int64', 'float64']:
        Q1 = df_clean[col].quantile(0.25)
        Q3 = df_clean[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers = ((df_clean[col] < lower_bound) | (df_clean[col] > upper_bound)).sum()
        print(f"\n{col}:")
        print(f"   Q1: {Q1:.2f}, Q3: {Q3:.2f}, IQR: {IQR:.2f}")
        print(f"   Límites: [{lower_bound:.2f}, {upper_bound:.2f}]")
        print(f"   Outliers: {outliers} ({outliers/len(df_clean)*100:.2f}%)")
# Out:
# n_tokens_title:
#    Q1: 9.00, Q3: 12.00, IQR: 3.00
#    Límites: [4.50, 16.50]
#    Outliers: 562 (1.39%)
#
# n_tokens_content:
#    Q1: 247.00, Q3: 725.00, IQR: 478.00
#    Límites: [-470.00, 1442.00]
#    Outliers: 2042 (5.05%)
#
# num_hrefs:
#    Q1: 4.00, Q3: 14.00, IQR: 10.00
#    Límites: [-11.00, 29.00]
#    Outliers: 2561 (6.33%)
#
# num_imgs:
#    Q1: 1.00, Q3: 5.00, IQR: 4.00
#    Límites: [-5.00, 11.00]
#    Outliers: 5501 (13.60%)
#
# num_videos:
#    Q1: 0.00, Q3: 1.00, IQR: 1.00
#    Límites: [-1.50, 2.50]
#    Outliers: 3181 (7.87%)
#
# shares:
#    Q1: 950.00, Q3: 2800.00, IQR: 1850.00
#    Límites: [-1825.00, 5575.00]
#    Outliers: 4728 (11.69%)

# %%
# Eliminar duplicados
rows_before = len(df_clean)
duplicates_removed = df_clean.duplicated().sum()
df_clean = df_clean.drop_duplicates()
print(f"\n1. Duplicados eliminados: {duplicates_removed}")

# Eliminar filas con demasiados valores nulos (más del 50%)
threshold = len(df_clean.columns) * 0.5
rows_with_many_nulls = df_clean.isnull().sum(axis=1) > threshold
df_clean = df_clean[~rows_with_many_nulls]
print(f"2. Filas con >50% nulos eliminadas: {rows_with_many_nulls.sum()}")

# Eliminar columnas con demasiados valores nulos (más del 50%)
null_percentages = (df_clean.isnull().sum() / len(df_clean)) * 100
cols_to_drop = null_percentages[null_percentages > 50].index.tolist()
if cols_to_drop:
    df_clean = df_clean.drop(columns=cols_to_drop)
    print(f"3. Columnas con >50% nulos eliminadas: {cols_to_drop}")
else:
    print(f"3. No hay columnas con >50% nulos")

# Imputar valores nulos en columnas numéricas NO booleanas con la mediana
numeric_cols_with_nulls = df_clean.select_dtypes(include=[np.number]).columns[
    df_clean.select_dtypes(include=[np.number]).isnull().any()
].tolist()

# Excluir columnas booleanas de la imputación con mediana
numeric_cols_for_imputation = [col for col in numeric_cols_with_nulls if col not in boolean_cols]

if numeric_cols_for_imputation:
    print(f"\n4. Imputando valores nulos en columnas numéricas (NO booleanas) con la mediana:")
    for col in numeric_cols_for_imputation:
        median_val = df_clean[col].median()
        nulls_count = df_clean[col].isnull().sum()
        df_clean.loc[:, col] = df_clean[col].fillna(median_val)
        print(f"   - {col}: {nulls_count} valores imputados con {median_val:.2f}")
else:
    print(f"\n4. ✓ No hay valores nulos en columnas numéricas (NO booleanas) para imputar")

# Imputar valores nulos en columnas booleanas con 0 (valor más conservador)
boolean_cols_with_nulls = [col for col in boolean_cols if col in df_clean.columns and df_clean[col].isnull().any()]
if boolean_cols_with_nulls:
    print(f"\n5. Imputando valores nulos en columnas booleanas con 0:")
    for col in boolean_cols_with_nulls:
        nulls_count = df_clean[col].isnull().sum()
        df_clean.loc[:, col] = df_clean[col].fillna(0)
        print(f"   - {col}: {nulls_count} valores imputados con 0")
else:
    print(f"\n5. ✓ No hay valores nulos en columnas booleanas")

# Eliminar outliers extremos en shares (variable objetivo común)
if 'shares' in df_clean.columns:
    Q1 = df_clean['shares'].quantile(0.25)
    Q3 = df_clean['shares'].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 3 * IQR  # Usar 3*IQR para outliers extremos
    upper_bound = Q3 + 3 * IQR

    outliers_mask = (df_clean['shares'] < lower_bound) | (df_clean['shares'] > upper_bound)
    outliers_count = outliers_mask.sum()
    df_clean = df_clean[~outliers_mask]
    print(f"\n6. Outliers extremos en 'shares' eliminados: {outliers_count}")

# Eliminar valores negativos en columnas que no deberían tenerlos (excluyendo booleanas)
print("\n7. Verificando valores negativos en columnas que deberían ser positivas:")
positive_cols = ['n_tokens_title', 'n_tokens_content', 'num_hrefs', 'num_imgs',
                 'num_videos', 'shares']

negative_found = False
for col in positive_cols:
    if col in df_clean.columns and df_clean[col].dtype in ['int64', 'float64']:
        negative_mask = df_clean[col] < 0
        negative_count = negative_mask.sum()
        if negative_count > 0:
            df_clean = df_clean[~negative_mask]
            print(f"   - {col}: {negative_count} valores negativos eliminados")
            negative_found = True

if not negative_found:
    print("   ✓ No se encontraron valores negativos en las columnas verificadas")

rows_after = len(df_clean)
# Out:
# 1. Duplicados eliminados: 1
# 2. Filas con >50% nulos eliminadas: 0
# 3. No hay columnas con >50% nulos
#
# 4. Imputando valores nulos en columnas numéricas (NO booleanas) con la mediana:
#    - timedelta: 597 valores imputados con 342.00
#    - n_tokens_title: 614 valores imputados con 10.00
#    - n_tokens_content: 631 valores imputados con 413.00
#    - n_unique_tokens: 602 valores imputados con 0.54
#    - n_non_stop_words: 581 valores imputados con 1.00
#    - n_non_stop_unique_tokens: 637 valores imputados con 0.69
#    - num_hrefs: 597 valores imputados con 8.00
#    - num_self_hrefs: 608 valores imputados con 3.00
#    - num_imgs: 596 valores imputados con 1.00
#    - num_videos: 587 valores imputados con 0.00
#    - average_token_length: 534 valores imputados con 4.67
#    - num_keywords: 605 valores imputados con 7.00
#    - kw_min_min: 603 valores imputados con -1.00
#    - kw_max_min: 621 valores imputados con 664.00
#    - kw_avg_min: 613 valores imputados con 237.62
#    - kw_min_max: 601 valores imputados con 1400.00
#    - kw_max_max: 563 valores imputados con 843300.00
#    - kw_avg_max: 607 valores imputados con 245416.89
#    - kw_min_avg: 584 valores imputados con 1028.50
#    - kw_max_avg: 579 valores imputados con 4364.79
#    - kw_avg_avg: 538 valores imputados con 2877.41
#    - self_reference_min_shares: 604 valores imputados con 1200.00
#    - self_reference_max_shares: 594 valores imputados con 2900.00
#    - self_reference_avg_sharess: 620 valores imputados con 2200.00
#    - LDA_00: 628 valores imputados con 0.03
#    - LDA_01: 591 valores imputados con 0.03
#    - LDA_02: 629 valores imputados con 0.04
#    - LDA_03: 590 valores imputados con 0.04
#    - LDA_04: 601 valores imputados con 0.05
#    - global_subjectivity: 579 valores imputados con 0.45
#    - global_sentiment_polarity: 589 valores imputados con 0.12
#    - global_rate_positive_words: 575 valores imputados con 0.04
#    - global_rate_negative_words: 646 valores imputados con 0.02
#    - rate_positive_words: 596 valores imputados con 0.71
#    - rate_negative_words: 622 valores imputados con 0.28
#    - avg_positive_polarity: 603 valores imputados con 0.36
#    - min_positive_polarity: 633 valores imputados con 0.10
#    - max_positive_polarity: 604 valores imputados con 0.80
#    - avg_negative_polarity: 606 valores imputados con -0.25
#    - min_negative_polarity: 604 valores imputados con -0.50
#    - max_negative_polarity: 573 valores imputados con -0.10
#    - title_subjectivity: 601 valores imputados con 0.15
#    - title_sentiment_polarity: 627 valores imputados con 0.00
#    - abs_title_subjectivity: 628 valores imputados con 0.50
#    - abs_title_sentiment_polarity: 612 valores imputados con 0.00
#    - shares: 631 valores imputados con 1400.00
#    - mixed_type_col: 12056 valores imputados con 494.00
#
# 5. Imputando valores nulos en columnas booleanas con 0:
#    - data_channel_is_lifestyle: 613 valores imputados con 0
#    - data_channel_is_entertainment: 612 valores imputados con 0
#    - data_channel_is_bus: 548 valores imputados con 0
#    - data_channel_is_socmed: 642 valores imputados con 0
#    - data_channel_is_tech: 583 valores imputados con 0
#    - data_channel_is_world: 591 valores imputados con 0
#    - weekday_is_monday: 615 valores imputados con 0
#    - weekday_is_tuesday: 619 valores imputados con 0
#    - weekday_is_wednesday: 556 valores imputados con 0
#    - weekday_is_thursday: 604 valores imputados con 0
#    - weekday_is_friday: 591 valores imputados con 0
#    - weekday_is_saturday: 628 valores imputados con 0
#    - weekday_is_sunday: 618 valores imputados con 0
#    - is_weekend: 627 valores imputados con 0
#
# 6. Outliers extremos en 'shares' eliminados: 2964
#
# 7. Verificando valores negativos en columnas que deberían ser positivas:
#    ✓ No se encontraron valores negativos en las columnas verificadas

# %%
#RESUMEN FINAL
print("\n" + "="*80)
print("RESUMEN FINAL DE LIMPIEZA")
print("="*80)
print(f"\nFilas originales: {rows_before:,}")
print(f"Filas después de limpieza: {rows_after:,}")
print(f"Filas eliminadas: {rows_before - rows_after:,} ({(rows_before - rows_after)/rows_before*100:.2f}%)")
print(f"Columnas finales: {df_clean.shape[1]}")

print("\nValores nulos restantes:")
remaining_nulls = df_clean.isnull().sum().sum()
print(f"   Total: {remaining_nulls}")

# Guardar el dataset limpio
#df_clean.to_csv('online_news_clean.csv', index=False)
#print("\n✓ Dataset limpio guardado como 'online_news_clean.csv'")

print("\nPrimeras filas del dataset limpio:")
print(df_clean.head())

print("\nInformación del dataset limpio:")
print(df_clean.info())
# Out:
# ================================================================================
# RESUMEN FINAL DE LIMPIEZA
# ================================================================================
#
# Filas originales: 40,436
# Filas después de limpieza: 37,471
# Filas eliminadas: 2,965 (7.33%)
# Columnas finales: 62
#
# Valores nulos restantes:
#    Total: 373
#
# Primeras filas del dataset limpio:
#                                                  url  timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...      731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...      731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...      731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...      731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/      731.0
#
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0            12.0             219.0         0.663594               1.0
# 1             9.0             255.0         0.604743               1.0
# 2             9.0             211.0         0.575130               1.0
# 3             9.0             531.0         0.503788               1.0
# 4            13.0            1072.0         0.415646               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  ...  \
# 0                  0.815385        4.0             2.0       1.0  ...
# 1                  0.791946        3.0             1.0       1.0  ...
# 2                  0.663866        3.0             1.0       1.0  ...
# 3                  0.665635        9.0             0.0       1.0  ...
# 4                  0.540890       19.0            19.0      20.0  ...
#
#    max_positive_polarity  avg_negative_polarity  min_negative_polarity  \
# 0                    0.7              -0.350000                 -0.600
# 1                    0.7              -0.118750                 -0.125
# 2                    1.0              -0.466667                 -0.800
# 3                    0.8              -0.369697                 -0.600
# 4                    1.0              -0.220192                 -0.500
#
#    max_negative_polarity  title_subjectivity  title_sentiment_polarity  \
# 0              -3.400000            0.500000                 -0.187500
# 1              -0.100000            0.000000                  0.000000
# 2              -0.133333            0.000000                  0.000000
# 3              -0.166667            0.000000                  0.000000
# 4              -0.050000            0.454545                  0.136364
#
#    abs_title_subjectivity  abs_title_sentiment_polarity  shares  \
# 0                0.000000                      0.187500   593.0
# 1                0.500000                      0.000000   711.0
# 2                0.500000                      0.000000  1500.0
# 3                0.500000                      0.000000  1200.0
# 4                0.045455                      0.136364   505.0
#
#    mixed_type_col
# 0           494.0
# 1           639.0
# 2           494.0
# 3           688.0
# 4           579.0
#
# [5 rows x 62 columns]
#
# Información del dataset limpio:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37471 entries, 0 to 40434
# Data columns (total 62 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            37098 non-null  object
#  1   timedelta                      37471 non-null  float64
#  2   n_tokens_title                 37471 non-null  float64
#  3   n_tokens_content               37471 non-null  float64
#  4   n_unique_tokens                37471 non-null  float64
#  5   n_non_stop_words               37471 non-null  float64
#  6   n_non_stop_unique_tokens       37471 non-null  float64
#  7   num_hrefs                      37471 non-null  float64
#  8   num_self_hrefs                 37471 non-null  float64
#  9   num_imgs                       37471 non-null  float64
#  10  num_videos                     37471 non-null  float64
#  11  average_token_length           37471 non-null  float64
#  12  num_keywords                   37471 non-null  float64
#  13  data_channel_is_lifestyle      37471 non-null  float64
#  14  data_channel_is_entertainment  37471 non-null  float64
#  15  data_channel_is_bus            37471 non-null  float64
#  16  data_channel_is_socmed         37471 non-null  float64
#  17  data_channel_is_tech           37471 non-null  float64
#  18  data_channel_is_world          37471 non-null  float64
#  19  kw_min_min                     37471 non-null  float64
#  20  kw_max_min                     37471 non-null  float64
#  21  kw_avg_min                     37471 non-null  float64
#  22  kw_min_max                     37471 non-null  float64
#  23  kw_max_max                     37471 non-null  float64
#  24  kw_avg_max                     37471 non-null  float64
#  25  kw_min_avg                     37471 non-null  float64
#  26  kw_max_avg                     37471 non-null  float64
#  27  kw_avg_avg                     37471 non-null  float64
#  28  self_reference_min_shares      37471 non-null  float64
#  29  self_reference_max_shares      37471 non-null  float64
#  30  self_reference_avg_sharess     37471 non-null  float64
#  31  weekday_is_monday              37471 non-null  float64
#  32  weekday_is_tuesday             37471 non-null  float64
#  33  weekday_is_wednesday           37471 non-null  float64
#  34  weekday_is_thursday            37471 non-null  float64
#  35  weekday_is_friday              37471 non-null  float64
#  36  weekday_is_saturday            37471 non-null  float64
#  37  weekday_is_sunday              37471 non-null  float64
#  38  is_weekend                     37471 non-null  float64
#  39  LDA_00                         37471 non-null  float64
#  40  LDA_01                         37471 non-null  float64
#  41  LDA_02                         37471 non-null  float64
#  42  LDA_03                         37471 non-null  float64
#  43  LDA_04                         37471 non-null  float64
#  44  global_subjectivity            37471 non-null  float64
#  45  global_sentiment_polarity      37471 non-null  float64
#  46  global_rate_positive_words     37471 non-null  float64
#  47  global_rate_negative_words     37471 non-null  float64
#  48  rate_positive_words            37471 non-null  float64
#  49  rate_negative_words            37471 non-null  float64
#  50  avg_positive_polarity          37471 non-null  float64
#  51  min_positive_polarity          37471 non-null  float64
#  52  max_positive_polarity          37471 non-null  float64
#  53  avg_negative_polarity          37471 non-null  float64
#  54  min_negative_polarity          37471 non-null  float64
#  55  max_negative_polarity          37471 non-null  float64
#  56  title_subjectivity             37471 non-null  float64
#  57  title_sentiment_polarity       37471 non-null  float64
#  58  abs_title_subjectivity         37471 non-null  float64
#  59  abs_title_sentiment_polarity   37471 non-null  float64
#  60  shares                         37471 non-null  float64
#  61  mixed_type_col                 37471 non-null  float64
# dtypes: float64(61), object(1)
# memory usage: 18.0+ MB
# None

# %% [markdown]
# # **Parte 2**. Preprocesamiento
